# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import os
import imageio
import cv2

SAMPLE_NAME = "DBS_bT20"
FLUORO_FILE_NAME = os.path.join(SAMPLE_NAME,"fluoro20.tif")

fluoro = imageio.imread(FLUORO_FILE_NAME)
fluoro = cv2.cvtColor(fluoro, cv2.COLOR_BGR2GRAY)

plt.imshow(fluoro)
# Out:
# C:\Users\VukadinoviM\AppData\Local\Temp\ipykernel_37964\1114651250.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   fluoro = imageio.imread(FLUORO_FILE_NAME)
# <img src="data:image/png;base64,..." width="640.2">

# %%
# 694 x 331
# 753 x 318
# 813 x 314 
# 876 x 313
# 932 x 320
# 991 x 334
# 1048 x 352
